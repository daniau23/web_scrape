# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from bs4 import BeautifulSoup
import requests
from csv import writer

# %%
url = "https://www.pararius.com/apartments/amsterdam?ac=1"

# %%
page = requests.get(url)
print(page)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <link href="https://cdn.cookielaw.org" rel="preconnect"/>
# <script data-document-language="true" data-domain-script="830efbbc-d64d-4d58-9372-fb677f7af069" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js"></script>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <script>
#             (function (htmlNode) {
#                 htmlNode.classList.add('has-js');
#             })(document.documentElement);
#
#             var Platform = {
#                 locale: 'en',
#                 uris: {
#                     autocomplete: '/api/autocomplete',
#                     get_search_urls: '/frontend/get-search-urls',
#                     maps: 'https://www.pararius.nl/api/map',
#                     recent_searches: '/api/recent-searches',
#                 },
#                 keys: {
#                     google_maps: 'AIzaSyB4A8QStGC5kdGtGxwO6AfzYTgijUBV1Z4',
#                     mapbox: 'pk.eyJ1IjoidHJlZWhvdXNlIiwiYSI6ImNqOGsxcTEwajA3MDgyd28zOWd5dXJ0YXcifQ.0PYYxJ09bTgq60eTB2Br0Q'
#                 },
#                 bundles: {
#                     mapbox: '/frontend/assets/bundle/Shared/Vendor/Mapbox/Mapbox-202e56c69f.js'
#                 },
#                 enabled_feature_toggles: '\u005B\u005D'
#             };
#
#             var googletag = googletag || {};
#             googletag.cmd = googletag.cmd || [];
#         </script>
# <title>Rental Apartments Amsterdam</title>
# <meta charset="utf-8"/>
# <meta content="Find rental apartments in Amsterdam. With 537 properties for rent in Amsterdam, Pararius has the largest amount of rental apartments." name="description">
# <meta content="noindex,follow" name="robots">
# <meta content="Find rental apartments in Amsterdam. With 537 properties for rent in Amsterdam, Pararius has the largest amount of rental apartments." property="og:description"/>
# <meta content="https://www.pararius.com/apartments/amsterdam" property="og:url"/>
# <link href="https://www.pararius.com/apartments/amsterdam" rel="canonical"/>
# <link href="https://www.pararius.nl/huurwoningen/amsterdam" hreflang="nl" rel="alternate"/>
# <link href="https://www.pararius.com/apartments/amsterdam" hreflang="en" rel="alternate"/>
# <link href="https://www.pararius.com/mietwohnungen/amsterdam" hreflang="de" rel="alternate"/>
# <link href="https://www.pararius.com/appartamenti/amsterdam" hreflang="it" rel="alternate"/>
# <link href="https://www.pararius.com/appartements/amsterdam" hreflang="fr" rel="alternate"/>
# <link href="https://www.pararius.com/pisos/amsterdam" hreflang="es" rel="alternate"/>
# <link href="//www.google-analytics.com" rel="preconnect"/>
# <link href="//connect.facebook.net" rel="preconnect"/>
# <script>
#     window['gtag_enable_tcf_support'] = true;
# </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-742557-1"></script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#     gtag('config', 'UA-742557-1', {
#         'optimize_id': 'OPT-PRVC8GP',
#         'anonymize_ip': true,
#         'forceSSL': true,
#         'layout': 'layout2',
#         'extension': '.com',
#         'section': 'NOSHORTSTAY',
#         'custom_map': {
#             'dimension1': 'layout',
#             'dimension2': 'extension',
#             'dimension3': 'section',
#         }
#     });
#     gtag('config', 'G-YCYTBWR959', {
#         'forceSSL': true,
#         'layout': 'layout2',
#         'extension': '.com',
#         'section': 'NOSHORTSTAY',
#         'custom_map': {
#             'dimension1': 'layout',
#             'dimension2': 'extension',
#             'dimension3': 'section',
#         }
#     });
# </script>
# <script class="optanon-category-C0004" type="text/plain">
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window, document,'script',
#     'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '855720297872780');
#     fbq('track', 'PageView');
# </script>
# <link href="//tpc.googlesyndication.com" rel="preconnect"/>
# <link href="//ad.doubleclick.net" rel="preconnect"/>
# <script async="" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <link href="https://www.pararius.com/apartments/amsterdam/page-2" rel="next"/>
# <link as="font" href="/frontend/assets/Pararius/Font/Open-Sans-Latin-Bold-5717b08cf6.woff2" rel="preload"/>
# <link as="font" href="/frontend/assets/Pararius/Font/Open-Sans-Latin-Regular-be21e759f9.woff2" rel="preload"/>
# <link href="/frontend/assets/bundle/Pararius/Pararius-8be21baf27.css" rel="stylesheet"/>
# <link href="/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="/browserconfig.xml" name="msapplication-config">
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/ms-icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <script async="" src="/frontend/assets/bundle/Shared/Vendor/Prebid/Prebid6-76b269950f.6.0.js"></script>
# <script>
#             function getType () {
#                 var types = ['mobile', 'tablet', 'desktop'];
#                 var len = types.length;
#                 var content;
#
#                 if (typeof getComputedStyle === 'function') {
#                     content = window.getComputedStyle(document.body, ':after').getPropertyValue('content');
#
#                     while (len--) {
#                         if (content.indexOf(types[len]) !== -1) {
#                             return types[len];
#                         }
#                     }
#                 }
#
#                 return types[0];
#             }
#
#             var gam_lb_sizes = [[468, 60], [728, 90]];
#             var gam_lb_bb_sizes = [[728, 90], [970, 90], [970, 250]];
#             var gam_mobile_sizes = [[300, 250], [320, 50], [320, 100]];
#             var gam_mobile_xs_sizes = [[320, 50], [320, 100]];
#             var gam_infeed_desktop_sizes = [[468, 60], [728, 90], [1000, 200], 'fluid'];
#             var gam_infeed_mobile_sizes = [[300, 250], [1000, 200], 'fluid'];
#             var gam_only_lb_sizes = [[468, 60], [728, 90], 'fluid'];
#             var gam_only_mobile_xs_sizes = [[320, 50], [320, 100], [320, 100], 'fluid'];
#             var gam_only_mobile_sizes = [[300, 250], [320, 50], [320, 100], [300, 600],  [320, 480], 'fluid'];
#
#             var prebid_adunits = [
#                 {
#                     code: 'para-serp-web-bblb',
#                     mediaTypes: {
#                         banner: {
#                             sizes: gam_lb_bb_sizes
#                         }
#                     },
#                     bids: [
#                         {
#                             bidder: 'appnexus',
#                             labelAny: ["desktop"],
#                             params: {
#                                 placementId: 20168335
#                             }
#                         }
#                     ]
#                 },
#                 {
#                     code: 'para-serp-web-lb1',
#                     mediaTypes: {
#                         banner: {
#                             sizes: gam_lb_sizes
#                         }
#                     },
#                     bids: [
#                         {
#                             bidder: 'appnexus',
#                             labelAny: ["desktop"],
#                             params: {
#                                 placementId: 20168337
#                             }
#                         }
#                     ]
#                 },
#                 {
#                     code: 'para-serp-web-lb2',
#                     mediaTypes: {
#                         banner: {
#                             sizes: gam_lb_sizes
#                         }
#                     },
#                     bids: [
#                         {
#                             bidder: 'appnexus',
#                             labelAny: ["desktop"],
#                             params: {
#                                 placementId: 20168339
#                             }
#                         }
#                     ]
#                 },
#                 {
#                     code: 'para-serp-web-lb3',
#                     mediaTypes: {
#                         banner: {
#                             sizes: gam_lb_sizes
#                         }
#                     },
#                     bids: [
#                         {
#                             bidder: 'appnexus',
#                             labelAll: ["desktop"],
#                             params: {
#                                 placementId: 20168340
#                             }
#                         }
#                     ]
#                 },
#                 {
#                     code: 'para-serp-web-bbll',
#                     mediaTypes: {
#                         banner: {
#                             sizes: gam_lb_bb_sizes
#                         }
#                     },
#                     bids: [
#                         {
#                             bidder: 'appnexus',
#                             labelAny: ["desktop"],
#                             params: {
#                                 placementId: 20168341
#                             }
#                         }
#                     ]
#                 },
#                 {
#                     code: 'para-serp-mob-db1',
#                     mediaTypes: {
#                         banner: {
#                             sizes: gam_mobile_xs_sizes
#                         }
#                     },
#                     bids: [
#                         {
#                             bidder: 'appnexus',
#                             labelAny: ["mobile"],
#                             params: {
#                                 placementId: 20168342
#                             }
#                         }
#                     ]
#                 },
#                 {
#                     code: 'para-serp-mob-db2',
#                     mediaTypes: {
#                         banner: {
#                             sizes: gam_mobile_xs_sizes
#                         }
#                     },
#                     bids: [
#                         {
#                             bidder: 'appnexus',
#                             labelAny: ["mobile"],
#                             params: {
#                                 placementId: 20168343
#                             }
#                         }
#                     ]
#                 },
#                 {
#                     code: 'para-serp-mob-db3',
#                     mediaTypes: {
#                         banner: {
#                             sizes: gam_mobile_xs_sizes
#                         }
#                     },
#                     bids: [
#                         {
#                             bidder: 'appnexus',
#                             labelAny: ["mobile"],
#                             params: {
#                                 placementId: 20168344
#                             }
#                         }
#                     ]
#                 },
#                 {
#                     code: 'para-serp-mob-mr',
#                     mediaTypes: {
#                         banner: {
#                             sizes: gam_mobile_sizes
#                         }
#                     },
#                     bids: [
#                         {
#                             bidder: 'appnexus',
#                             labelAny: ["mobile"],
#                             params: {
#                                 placementId: 20168345
#                             }
#                         }
#                     ]
#                 }
#             ];
#
#             var PREBID_TIMEOUT = 1000;
#             var FAILSAFE_TIMEOUT = 3000;
#
#             var googletag = googletag || {};
#             googletag.cmd = googletag.cmd || [];
#             googletag.cmd.push(function() {
#                 googletag.pubads().disableInitialLoad();
#             });
#
#             var pbjs = pbjs || {};
#             pbjs.que = pbjs.que || [];
#
#             pbjs.que.push(function() {
#                 pbjs.addAdUnits(prebid_adunits);
#                 pbjs.setConfig({
#                     sizeConfig: [
#                         {
#                             'mediaQuery': '(min-width: 1024px)',
#                             'labels': ['desktop']
#                         }, {
#                             'mediaQuery': '(min-width: 300px) and (max-width: 739px)',
#                             'labels': ['mobile']
#                         }
#                     ],
#                     consentManagement: {
#                         gdpr: {
#                             cmpApi: 'iab',
#                             timeout: 8000,
#                             defaultGdprScope: true
#                         }
#                     }
#                 });
#                 pbjs.requestBids({
#                     bidsBackHandler: initAdserver,
#                     timeout: PREBID_TIMEOUT
#                 });
#             });
#
#             function initAdserver() {
#                 if (pbjs.initAdserverSet) return;
#                 pbjs.initAdserverSet = true;
#                 googletag.cmd.push(function() {
#                     pbjs.que.push(function() {
#                         pbjs.setTargetingForGPTAsync();
#                         googletag.pubads().refresh();
#                     });
#                 });
#             }
#
#             setTimeout(function() {
#                 initAdserver();
#             }, FAILSAFE_TIMEOUT);
#
#             googletag.cmd.push(function() {
#                 var gam_lb_bb_mapping = googletag.sizeMapping()
#                                             .addSize([1024, 0], gam_lb_bb_sizes)
#                                             .addSize([813, 0], [[728, 90]])
#                                             .addSize([0, 0], [])
#                                             .build();
#
#                 var web_lb_mapping = googletag.sizeMapping()
#                                             .addSize([813, 0], gam_only_lb_sizes)
#                                             .addSize([0, 0], [])
#                                             .build();
#
#                 var mob_db_mapping = googletag.sizeMapping()
#                                             .addSize([813, 0], [])
#                                             .addSize([300, 0], gam_only_mobile_xs_sizes)
#                                             .addSize([0, 0], [])
#                                             .build();
#
#                 var mob_mr_mapping = googletag.sizeMapping()
#                                             .addSize([813, 0], [])
#                                             .addSize([300, 0], gam_only_mobile_sizes)
#                                             .addSize([0, 0], [])
#                                             .build();
#
#                 var infeed_mapping = googletag.sizeMapping()
#                                             .addSize([813, 0], gam_infeed_desktop_sizes)
#                                             .addSize([300, 0], gam_infeed_mobile_sizes)
#                                             .addSize([0, 0], [])
#                                             .build();
#
#                                     googletag.defineSlot('/3987669/PARARIUS/PARA_SERP_WEB_BBLB', gam_lb_bb_sizes, 'para-serp-web-bblb').defineSizeMapping(gam_lb_bb_mapping).addService(googletag.pubads());
#                     googletag.defineSlot('/3987669/PARARIUS/PARA_SERP_WEB_LB1', gam_lb_sizes, 'para-serp-web-lb1').defineSizeMapping(web_lb_mapping).addService(googletag.pubads());
#                     googletag.defineSlot('/3987669/PARARIUS/PARA_SERP_WEB_LB2', gam_lb_sizes, 'para-serp-web-lb2').defineSizeMapping(web_lb_mapping).addService(googletag.pubads());
#                     googletag.defineSlot('/3987669/PARARIUS/PARA_SERP_WEB_LB3', gam_lb_sizes, 'para-serp-web-lb3').defineSizeMapping(web_lb_mapping).addService(googletag.pubads());
#                     googletag.defineSlot('/3987669/PARARIUS/PARA_SERP_WEB_BBLL', gam_lb_bb_sizes, 'para-serp-web-bbll').defineSizeMapping(gam_lb_bb_mapping).addService(googletag.pubads());
#
#                     googletag.defineSlot('/3987669/PARARIUS/PARA_SERP_MOB_DB1', gam_mobile_xs_sizes, 'para-serp-mob-db1').defineSizeMapping(mob_db_mapping).addService(googletag.pubads());
#                     googletag.defineSlot('/3987669/PARARIUS/PARA_SERP_MOB_DB2', gam_mobile_xs_sizes, 'para-serp-mob-db2').defineSizeMapping(mob_db_mapping).addService(googletag.pubads());
#                     googletag.defineSlot('/3987669/PARARIUS/PARA_SERP_MOB_DB3', gam_mobile_xs_sizes, 'para-serp-mob-db3').defineSizeMapping(mob_db_mapping).addService(googletag.pubads());
#                     googletag.defineSlot('/3987669/PARARIUS/PARA_SERP_MOB_MR', gam_mobile_sizes, 'para-serp-mob-mr').defineSizeMapping(mob_mr_mapping).addService(googletag.pubads());
#
#                 googletag.defineSlot('/3987669/PARA_SERP_INFEED1', [[1000, 200]], 'para-serp-infeed1').addService(googletag.pubads());
#
#                 googletag.defineSlot('/3987669/PARA_SERP_INFEED2', [[300, 250], [468, 60], [728, 90], [1000, 200], 'fluid'], 'para-serp-infeed2').defineSizeMapping(infeed_mapping).addService(googletag.pubads());
#
#                 googletag.defineSlot('/3987669/PARA_SERP_INFEED3', [[1000, 200]], 'para-serp-infeed3').addService(googletag.pubads());
#                 googletag.defineSlot('/3987669/PARA_SERP_INFEED4', [[1000, 200]], 'para-serp-infeed4').addService(googletag.pubads());
#                 googletag.defineSlot('/3987669/PARA_SERP_INFEED5', [[1000, 200]], 'para-serp-infeed5').addService(googletag.pubads());
#
#                 var deviceType = getType() == 'desktop' ? 'desktop' : 'mobile';
#
#                 googletag.pubads().setTargeting('range', ['2200-5000']).setTargeting('device', [deviceType]).setTargeting('city', ['Amsterdam']).setTargeting('env', ['production']).setTargeting('section', ['NORMAL']).setTargeting('language', ['EN']).setTargeting('province', ['Noord-Holland']);
#                 googletag.pubads().enableSingleRequest();
#                 googletag.pubads().collapseEmptyDivs();
#                 googletag.pubads().enableLazyLoad({
#                     fetchMarginPercent: 500,  // Fetch slots within 5 viewports.
#                     renderMarginPercent: 200,  // Render slots within 2 viewports.
#                     mobileScaling: 2.0  // Double the above values on mobile.
#                 });
#                 googletag.enableServices();
#             });
#         </script>
# </meta></meta></meta></head>
# <body class="page page--search" data-controller="search-page" data-search-page-filters='{"filters":{"type":"for_rent","city":"amsterdam","lat":52.373436811306,"lon":4.9045250766617}}' data-search-page-sorting-options='{"sorting_options":[]}' data-search-page-view-options='{"view_options":{"view":"list","page":1}}'>
# <div class="page__notifications">
# </div>
# <div class="page__wrapper page__wrapper--masthead">
# <div class="page__row page__row--masthead">
# <header class="masthead" data-controller="masthead" role="banner">
# <a class="masthead__logo" href="/english">Pararius</a>
# <div class="masthead__search">
# <form action="" class="masthead__search-form" method="get">
# <div class="autocomplete autocomplete--masthead" data-autocomplete-i18n='{"no_results":"No results found","result_type_labels":{"country":"country","municipality":"municipality","city":"city","city_area":"area","district":"district","neighbourhood":"neighbourhood","street":"street","address":"address"}}' data-autocomplete-location-types='["city","city_area","district","neighbourhood","street"]' data-autocomplete-scope="masthead" data-controller="autocomplete">
# <div class="autocomplete__control-wrapper">
# <div class="autocomplete__control">
# <input autocomplete="off" class="autocomplete__input" data-action="keydown-&gt;autocomplete#onKeyDown keyup-&gt;autocomplete#onKeyUp keypress-&gt;autocomplete#onKeyPress focus-&gt;autocomplete#onFocus blur-&gt;autocomplete#onBlur" id="autocomplete-358152851" name="q" placeholder="City, district, neighbourhood or street" type="text" value=""/>
# <button aria-label="Search" class="autocomplete__button autocomplete__button--clear autocomplete__button--hidden" data-action="click-&gt;autocomplete#onClearClick" type="button"><svg viewbox="0 0 23 23" xmlns="http://www.w3.org/2000/svg">
# <path d="M2.98 20.268L19.95 3.297M3 3l16.97 16.97" fill="none" stroke="currentcolor" stroke-linecap="square" stroke-width="3"></path>
# </svg></button>
# <ul class="autocomplete__list" data-action="click-&gt;autocomplete#onClick"></ul>
# </div>
# <button aria-label="Search" class="autocomplete__button autocomplete__button--accept" data-action="click-&gt;autocomplete#onAcceptClick" name="search" type="button">
# <span class="autocomplete__button-label autocomplete__button-label--accept">Search</span>
# </button>
# </div>
# </div>
# </form>
# </div>
# <nav class="masthead__navigation">
# <a class="masthead__link masthead__link--login" href="/login?_target_path=/apartments/amsterdam" rel="nofollow">Login</a>
# <a class="masthead__link masthead__link--profile" href="/login?_target_path=/apartments/amsterdam" rel="nofollow">Login</a>
# <div class="masthead__language-switcher">
# <div class="language-switcher language-switcher--selected-en" data-controller="language-switcher">
# <button class="language-switcher__toggle language-switcher__toggle--en" data-action="click-&gt;language-switcher#toggle" type="button">Show/ hide language choice</button>
# <ul class="language-switcher__options">
# <li class="language-switcher__option">
# <a class="language-switcher__option-label language-switcher__option-label--nl" href="/huurwoningen/amsterdam">Nederlands</a>
# </li>
# <li class="language-switcher__option language-switcher__option--selected">
# <span class="language-switcher__option-label language-switcher__option-label--en">English</span>
# </li>
# <li class="language-switcher__option">
# <a class="language-switcher__option-label language-switcher__option-label--es" href="/pisos/amsterdam">Español</a>
# </li>
# <li class="language-switcher__option">
# <a class="language-switcher__option-label language-switcher__option-label--it" href="/appartamenti/amsterdam">Italiano</a>
# </li>
# <li class="language-switcher__option">
# <a class="language-switcher__option-label language-switcher__option-label--de" href="/mietwohnungen/amsterdam">Deutsch</a>
# </li>
# <li class="language-switcher__option">
# <a class="language-switcher__option-label language-switcher__option-label--fr" href="/appartements/amsterdam">Français</a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# </header>
# </div>
# </div>
# <div class="page__content">
# <div class="page__wrapper page__wrapper--search-controls">
# <div class="search-controls" data-controller="search-controls">
# <div class="search-controls__autocomplete">
# <div class="search-controls__container search-controls__container--autocomplete">
# <div class="autocomplete autocomplete--search-controls" data-autocomplete-i18n='{"no_results":"No results found","result_type_labels":{"country":"country","municipality":"municipality","city":"city","city_area":"area","district":"district","neighbourhood":"neighbourhood","street":"street","address":"address"}}' data-autocomplete-location-types='["city"]' data-autocomplete-scope="search-controls" data-controller="autocomplete">
# <div class="autocomplete__control-wrapper">
# <div class="autocomplete__control">
# <input autocomplete="off" class="autocomplete__input" data-action="keydown-&gt;autocomplete#onKeyDown keyup-&gt;autocomplete#onKeyUp keypress-&gt;autocomplete#onKeyPress focus-&gt;autocomplete#onFocus blur-&gt;autocomplete#onBlur" id="autocomplete-767036765" name="" placeholder="City, district, neighbourhood or address" type="text" value="Amsterdam"/>
# <button aria-label="Search" class="autocomplete__button autocomplete__button--clear autocomplete__button--hidden" data-action="click-&gt;autocomplete#onClearClick" type="button"><svg viewbox="0 0 23 23" xmlns="http://www.w3.org/2000/svg">
# <path d="M2.98 20.268L19.95 3.297M3 3l16.97 16.97" fill="none" stroke="currentcolor" stroke-linecap="square" stroke-width="3"></path>
# </svg></button>
# <ul class="autocomplete__list" data-action="click-&gt;autocomplete#onClick"></ul>
# </div>
# <button aria-label="Search" class="autocomplete__button autocomplete__button--accept" data-action="click-&gt;autocomplete#onAcceptClick" name="search" type="button">
# <span class="autocomplete__button-label autocomplete__button-label--accept">Search</span>
# </button>
# </div>
# </div>
# </div>
# </div>
# <div class="search-controls__other-controls">
# <div class="search-controls__container search-controls__container--other-controls">
# <div class="search-controls__filters-toggle">
# <button class="search-controls__button search-controls__button--filter-toggle" data-action="click-&gt;search-controls#onSearchFiltersButtonClick" data-count="1" type="button">
#                         Filters
#                     </button>
# </div>
# <div class="search-controls__quick-access-filters">
# <form class="quick-access-filters" data-action="submit-&gt;quick-access-filters#onSubmit" data-controller="quick-access-filters">
# <div class="quick-access-filters__search-filters-group quick-access-filters__search-filters-group--price">
# <div class="search-filters-group search-filters-group--quick-access-filters" data-controller="search-filters-group" data-search-filters-group-name="price">
# <div class="search-filters-group__button">
# <button class="search-filters-group__button search-filters-group__button--toggle" data-action="click-&gt;search-filters-group#onToggleClick" type="button">
# <span class="button__label">Price</span>
# </button>
# </div>
# <div class="search-filters-group__filters">
# <button class="search-filters-group__close" data-action="click-&gt;search-filters-group#onCloseClick" type="button">Close</button>
# <div class="search-filters-group__item search-filters-group__item--price">
# <div class="search-filter search-filter--price" data-controller="search-filter">
# <h4 class="search-filter__label">
#                                     Price
#                             </h4>
# <div class="search-filter__content">
# <div class="range-control" data-controller="range-control">
# <ul class="range-control__controls">
# <li class="range-control__select-control range-control__select-control--min">
# <div class="select-control select-control--has-value" data-controller="select-control">
# <label class="select-control__label" for="select-control-648361350">From</label>
# <select class="select-control__control" data-action="change-&gt;select-control#onChange" id="select-control-648361350" name="filters[price][min]">
# <option selected="selected" value="">No preference</option>
# <option value="200">€200</option>
# <option value="300">€300</option>
# <option value="400">€400</option>
# <option value="500">€500</option>
# <option value="600">€600</option>
# <option value="700">€700</option>
# <option value="800">€800</option>
# <option value="900">€900</option>
# <option value="1000">€1,000</option>
# <option value="1100">€1,100</option>
# <option value="1200">€1,200</option>
# <option value="1300">€1,300</option>
# <option value="1400">€1,400</option>
# <option value="1500">€1,500</option>
# <option value="1750">€1,750</option>
# <option value="2000">€2,000</option>
# <option value="2250">€2,250</option>
# <option value="2500">€2,500</option>
# <option value="3000">€3,000</option>
# <option value="4000">€4,000</option>
# <option value="6000">€6,000</option>
# </select>
# </div>
# </li>
# <li class="range-control__select-control range-control__select-control--max">
# <div class="select-control select-control--has-value" data-controller="select-control">
# <label class="select-control__label" for="select-control-531971936">To</label>
# <select class="select-control__control" data-action="change-&gt;select-control#onChange" id="select-control-531971936" name="filters[price][max]">
# <option selected="selected" value="">No preference</option>
# <option value="200">€200</option>
# <option value="300">€300</option>
# <option value="400">€400</option>
# <option value="500">€500</option>
# <option value="600">€600</option>
# <option value="700">€700</option>
# <option value="800">€800</option>
# <option value="900">€900</option>
# <option value="1000">€1,000</option>
# <option value="1100">€1,100</option>
# <option value="1200">€1,200</option>
# <option value="1300">€1,300</option>
# <option value="1400">€1,400</option>
# <option value="1500">€1,500</option>
# <option value="1750">€1,750</option>
# <option value="2000">€2,000</option>
# <option value="2250">€2,250</option>
# <option value="2500">€2,500</option>
# <option value="3000">€3,000</option>
# <option value="4000">€4,000</option>
# <option value="6000">€6,000</option>
# </select>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="quick-access-filters__search-filters-group quick-access-filters__search-filters-group--bedrooms">
# <div class="search-filters-group search-filters-group--quick-access-filters" data-controller="search-filters-group" data-search-filters-group-name="bedrooms">
# <div class="search-filters-group__button">
# <button class="search-filters-group__button search-filters-group__button--toggle" data-action="click-&gt;search-filters-group#onToggleClick" type="button">
# <span class="button__label">Bedrooms</span>
# </button>
# </div>
# <div class="search-filters-group__filters">
# <button class="search-filters-group__close" data-action="click-&gt;search-filters-group#onCloseClick" type="button">Close</button>
# <div class="search-filters-group__item search-filters-group__item--bedrooms">
# <div class="search-filter search-filter--bedrooms" data-controller="search-filter">
# <h4 class="search-filter__label">
#                                     Bedrooms
#                             </h4>
# <div class="search-filter__content">
# <div class="radio-control radio-control--search-filter" data-controller="radio-control">
# <input class="radio-control__control" id="radio-control-944043186" name="filters[bedrooms][min]" type="radio" value="1"/>
# <label class="radio-control__label" for="radio-control-944043186">
#                 1+
#                                                     <span class="radio-control__amount">527</span>
# </label>
# </div>
# <div class="radio-control radio-control--search-filter" data-controller="radio-control">
# <input class="radio-control__control" id="radio-control-594420314" name="filters[bedrooms][min]" type="radio" value="2"/>
# <label class="radio-control__label" for="radio-control-594420314">
#                 2+
#                                                     <span class="radio-control__amount">397</span>
# </label>
# </div>
# <div class="radio-control radio-control--search-filter" data-controller="radio-control">
# <input class="radio-control__control" id="radio-control-1753793297" name="filters[bedrooms][min]" type="radio" value="3"/>
# <label class="radio-control__label" for="radio-control-1753793297">
#                 3+
#                                                     <span class="radio-control__amount">160</span>
# </label>
# </div>
# <div class="radio-control radio-control--search-filter" data-controller="radio-control">
# <input class="radio-control__control" id="radio-control-2043049613" name="filters[bedrooms][min]" type="radio" value="4"/>
# <label class="radio-control__label" for="radio-control-2043049613">
#                 4+
#                                                     <span class="radio-control__amount">57</span>
# </label>
# </div>
# <div class="radio-control radio-control--search-filter" data-controller="radio-control">
# <input class="radio-control__control" id="radio-control-1731946993" name="filters[bedrooms][min]" type="radio" value="5"/>
# <label class="radio-control__label" for="radio-control-1731946993">
#                 5+
#                                                     <span class="radio-control__amount">15</span>
# </label>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="quick-access-filters__search-filters-group quick-access-filters__search-filters-group--living-size">
# <div class="search-filters-group search-filters-group--quick-access-filters" data-controller="search-filters-group" data-search-filters-group-name="living-size">
# <div class="search-filters-group__button">
# <button class="search-filters-group__button search-filters-group__button--toggle" data-action="click-&gt;search-filters-group#onToggleClick" type="button">
# <span class="button__label">Living size</span>
# </button>
# </div>
# <div class="search-filters-group__filters">
# <button class="search-filters-group__close" data-action="click-&gt;search-filters-group#onCloseClick" type="button">Close</button>
# <div class="search-filters-group__item search-filters-group__item--living-size">
# <div class="search-filter search-filter--living_size" data-controller="search-filter">
# <h4 class="search-filter__label">
#                                     Floor space
#                             </h4>
# <div class="search-filter__content">
# <div class="radio-control radio-control--search-filter" data-controller="radio-control">
# <input class="radio-control__control" id="radio-control-1385426208" name="filters[living_size][min]" type="radio" value="25"/>
# <label class="radio-control__label" for="radio-control-1385426208">
#                 25+ m2
#                                                     <span class="radio-control__amount">536</span>
# </label>
# </div>
# <div class="radio-control radio-control--search-filter" data-controller="radio-control">
# <input class="radio-control__control" id="radio-control-704458841" name="filters[living_size][min]" type="radio" value="50"/>
# <label class="radio-control__label" for="radio-control-704458841">
#                 50+ m2
#                                                     <span class="radio-control__amount">506</span>
# </label>
# </div>
# <div class="radio-control radio-control--search-filter" data-controller="radio-control">
# <input class="radio-control__control" id="radio-control-1717217773" name="filters[living_size][min]" type="radio" value="75"/>
# <label class="radio-control__label" for="radio-control-1717217773">
#                 75+ m2
#                                                     <span class="radio-control__amount">378</span>
# </label>
# </div>
# <div class="radio-control radio-control--search-filter" data-controller="radio-control">
# <input class="radio-control__control" id="radio-control-330413026" name="filters[living_size][min]" type="radio" value="100"/>
# <label class="radio-control__label" for="radio-control-330413026">
#                 100+ m2
#                                                     <span class="radio-control__amount">240</span>
# </label>
# </div>
# <div class="radio-control radio-control--search-filter" data-controller="radio-control">
# <input class="radio-control__control" id="radio-control-10928824" name="filters[living_size][min]" type="radio" value="125"/>
# <label class="radio-control__label" for="radio-control-10928824">
#                 125+ m2
#                                                     <span class="radio-control__amount">136</span>
# </label>
# </div>
# <div class="radio-control radio-control--search-filter" data-controller="radio-control">
# <input class="radio-control__control" id="radio-control-1424416862" name="filters[living_size][min]" type="radio" value="150"/>
# <label class="radio-control__label" for="radio-control-1424416862">
#                 150+ m2
#                                                     <span class="radio-control__amount">71</span>
# </label>
# </div>
# <div class="radio-control radio-control--search-filter" data-controller="radio-control">
# <input class="radio-control__control" id="radio-control-1318512709" name="filters[living_size][min]" type="radio" value="200"/>
# <label class="radio-control__label" for="radio-control-1318512709">
#                 200+ m2
#                                                     <span class="radio-control__amount">28</span>
# </label>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="quick-access-filters__search-filters-group quick-access-filters__search-filters-group--interior">
# <div class="search-filters-group search-filters-group--quick-access-filters" data-controller="search-filters-group" data-search-filters-group-name="interior">
# <div class="search-filters-group__button">
# <button class="search-filters-group__button search-filters-group__button--toggle" data-action="click-&gt;search-filters-group#onToggleClick" type="button">
# <span class="button__label">Interior</span>
# </button>
# </div>
# <div class="search-filters-group__filters">
# <button class="search-filters-group__close" data-action="click-&gt;search-filters-group#onCloseClick" type="button">Close</button>
# <div class="search-filters-group__item search-filters-group__item--interior">
# <div class="search-filter search-filter--interior" data-controller="search-filter">
# <h4 class="search-filter__label">
#                                     Interior
#                             </h4>
# <div class="search-filter__content">
# <div class="radio-control radio-control--search-filter" data-controller="radio-control">
# <input class="radio-control__control" id="radio-control-558509107" name="filters[interior]" type="radio" value="shell"/>
# <label class="radio-control__label" for="radio-control-558509107">
#                 Shell
#                                                     <span class="radio-control__amount">3</span>
# </label>
# </div>
# <div class="radio-control radio-control--search-filter" data-controller="radio-control">
# <input class="radio-control__control" id="radio-control-1233968471" name="filters[interior]" type="radio" value="upholstered"/>
# <label class="radio-control__label" for="radio-control-1233968471">
#                 Upholstered
#                                                     <span class="radio-control__amount">155</span>
# </label>
# </div>
# <div class="radio-control radio-control--search-filter" data-controller="radio-control">
# <input class="radio-control__control" id="radio-control-257436010" name="filters[interior]" type="radio" value="furnished"/>
# <label class="radio-control__label" for="radio-control-257436010">
#                 Furnished
#                                                     <span class="radio-control__amount">253</span>
# </label>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form>
# </div>
# <div class="search-controls__view-toggle">
# <a class="search-controls__button search-controls__button--view-toggle-map" href="/apartments/amsterdam/map" rel="nofollow">Map</a>
# </div>
# <div class="search-controls__mail-alert">
# <button class="search-controls__button search-controls__button--mail-alert" data-action="click-&gt;search-controls#onMailAlertButtonClick" type="button">
#                             Save
#                             <span>search</span>
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="modal modal--search-filters" data-controller="search-filters-modal">
# <div class="modal__header">
# <button class="modal__header-close-button" data-action="click-&gt;search-filters-modal#onCloseClick" type="button">Close</button>
# <h3>Filters</h3>
# </div>
# <div class="modal__body">
# <form action="/en/manual-search" class="search-filters" data-action="submit-&gt;search-filters#onSubmit" data-controller="search-filters" method="post">
# <div aria-multiselectable="true" aria-orientation="vertical" class="search-filters__filters" role="tablist">
# <div class="search-filters__summary">
# <div class="search-filters-summary" data-controller="search-filters-summary">
# <h5 class="search-filters-summary__header">Your search</h5>
# <ul class="search-filters-summary__list">
# <li class="search-filters-summary__item" data-filter-name="filters[city]">
# <span>Amsterdam</span>
# <button class="search-filters-summary__remove" data-action="click-&gt;search-filters-summary#onRemoveClick" type="button">
#                             Remove
#                         </button>
# </li>
# </ul>
# <button class="search-filters-summary__remove-all" data-action="click-&gt;search-filters-summary#onRemoveAllClick" type="button">
#                 Remove all filters
#             </button>
# </div>
# </div>
# <input name="filters[type]" type="hidden" value="for_rent"/>
# <input name="filters[country]" type="hidden" value=""/>
# <input name="filters[province]" type="hidden" value=""/>
# <div class="search-filters__filter search-filters__filter--price">
# <div class="search-filter search-filter--price" data-controller="search-filter">
# <h4 class="search-filter__label">
#                                     Price
#                             </h4>
# <div class="search-filter__content">
# <div class="range-control" data-controller="range-control">
# <ul class="range-control__controls">
# <li class="range-control__select-control range-control__select-control--min">
# <div class="select-control select-control--has-value" data-controller="select-control">
# <label class="select-control__label" for="select-control-1592686796">From</label>
# <select class="select-control__control" data-action="change-&gt;select-control#onChange" id="select-control-1592686796" name="filters[price][min]">
# <option selected="selected" value="">No preference</option>
# <option value="200">€200</option>
# <option value="300">€300</option>
# <option value="400">€400</option>
# <option value="500">€500</option>
# <option value="600">€600</option>
# <option value="700">€700</option>
# <option value="800">€800</option>
# <option value="900">€900</option>
# <option value="1000">€1,000</option>
# <option value="1100">€1,100</option>
# <option value="1200">€1,200</option>
# <option value="1300">€1,300</option>
# <option value="1400">€1,400</option>
# <option value="1500">€1,500</option>
# <option value="1750">€1,750</option>
# <option value="2000">€2,000</option>
# <option value="2250">€2,250</option>
# <option value="2500">€2,500</option>
# <option value="3000">€3,000</option>
# <option value="4000">€4,000</option>
# <option value="6000">€6,000</option>
# </select>
# </div>
# </li>
# <li class="range-control__select-control range-control__select-control--max">
# <div class="select-control select-control--has-value" data-controller="select-control">
# <label class="select-control__label" for="select-control-703301273">To</label>
# <select class="select-control__control" data-action="change-&gt;select-control#onChange" id="select-control-703301273" name="filters[price][max]">
# <option selected="selected" value="">No preference</option>
# <option value="200">€200</option>
# <option value="300">€300</option>
# <option value="400">€400</option>
# <option value="500">€500</option>
# <option value="600">€600</option>
# <option value="700">€700</option>
# <option value="800">€800</option>
# <option value="900">€900</option>
# <option value="1000">€1,000</option>
# <option value="1100">€1,100</option>
# <option value="1200">€1,200</option>
# <option value="1300">€1,300</option>
# <option value="1400">€1,400</option>
# <option value="1500">€1,500</option>
# <option value="1750">€1,750</option>
# <option value="2000">€2,000</option>
# <option value="2250">€2,250</option>
# <option value="2500">€2,500</option>
# <option value="3000">€3,000</option>
# <option value="4000">€4,000</option>
# <option value="6000">€6,000</option>
# </select>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="search-filters__filter search-filters__filter--dwelling_type">
# <div class="search-filter search-filter--dwelling_type" data-controller="search-filter">
# <h4 class="search-filter__label">
# <button aria-controls="panel-2702" aria-expanded="true" class="search-filter__collapse-toggle" data-action="click-&gt;search-filter#onCollapseToggleClick" id="toggle-2702" role="tab" type="button">Property type</button>
# </h4>
# <div aria-labelledby="toggle-2702" class="search-filter__content" id="panel-2702" role="tabpanel">
# <a class="search-filter__filter-link" data-action="click-&gt;search-filter#onFilterLinkClick" href="/apartments/amsterdam/apartment">
# <div class="radio-control radio-control--search-filter" data-controller="radio-control">
# <input class="radio-control__control" id="radio-control-816415199" name="filters[dwelling_type][]" type="radio" value="apartment"/>
# <label class="radio-control__label" for="radio-control-816415199">
#                 Apartment
#                                                     <span class="radio-control__amount">497</span>
# </label>
# </div>
# </a>
# <a class="search-filter__filter-link" data-action="click-&gt;search-filter#onFilterLinkClick" href="/apartments/amsterdam/house">
# <div class="radio-control radio-control--search-filter" data-controller="radio-control">
# <input class="radio-control__control" id="radio-control-1145268573" name="filters[dwelling_type][]" type="radio" value="house"/>
# <label class="radio-control__label" for="radio-control-1145268573">
#                 House
#                                                     <span class="radio-control__amount">35</span>
# </label>
# </div>
# </a>
# <a class="search-filter__filter-link" data-action="click-&gt;search-filter#onFilterLinkClick" href="/apartments/amsterdam/studio">
# <div class="radio-control radio-control--search-filter" data-controller="radio-control">
# <input class="radio-control__control" id="radio-control-1398969174" name="filters[dwelling_type][]" type="radio" value="studio"/>
# <label class="radio-control__label" for="radio-control-1398969174">
#                 Studio
#                                                     <span class="radio-control__amount">5</span>
# </label>
# </div>
# </a>
# <a class="search-filter__filter-link" data-action="click-&gt;search-filter#onFilterLinkClick" href="/apartments/amsterdam/room">
# <div class="radio-control radio-control--search-filter radio-control--disabled" data-controller="radio-control">
# <input class="radio-control__control" disabled="disabled" id="radio-control-1525789689" name="filters[dwelling_type][]" type="radio" value="room"/>
# <label class="radio-control__label" for="radio-control-1525789689">
#                 Room
#                                                     <span class="radio-control__amount">0</span>
# </label>
# </div>
# </a>
# </div>
# </div>
# </div>
# <div class="search-filters__filter search-filters__filter--city">
# <div class="search-filter search-filter--city" data-controller="search-filter">
# <h4 class="search-filter__label">
# <button aria-controls="panel-2410" aria-expanded="true" class="search-filter__collapse-toggle" data-action="click-&gt;search-filter#onCollapseToggleClick" id="toggle-2410" role="tab" type="button">City</button>
# </h4>
# <div aria-labelledby="toggle-2410" class="search-filter__content" id="panel-2410" role="tabpanel">
# <div class="radio-control radio-control--search-filter radio-control--clearable" data-controller="radio-control">
# <input checked="checked" class="radio-control__control" id="radio-control-110440018" name="filters[city]" type="radio" value="amsterdam"/>
# <label class="radio-control__label" for="radio-control-110440018">
#                 Amsterdam
#                                             </label>
# <button class="radio-control__clear-button" data-action="click-&gt;radio-control#onClearButtonClick" type="button">
#                 Clear value
#             </button>
# </div>
# </div>
# </div>
# </div>
# ...
# </picture>
# </div>
# </a>
# </div>
# <h2 class="listing-search-item__title">
# <a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/fd4b1755/biesboschstraat">
#
#             Apartment Biesboschstraat
#
#                             </a>
# </h2>
# <div class="listing-search-item__sub-title">
#             1078 MK Amsterdam (Scheldebuurt)
#         </div>
# <div class="listing-search-item__price">
#                 €2,100 per month
#             </div>
# <div class="listing-search-item__features">
# <ul class="illustrated-features illustrated-features--compact">
# <li class="illustrated-features__item illustrated-features__item--surface-area">80 m²</li>
# <li class="illustrated-features__item illustrated-features__item--number-of-rooms">3 rooms</li>
# <li class="illustrated-features__item illustrated-features__item--interior">Upholstered</li>
# </ul>
# </div>
# <div class="listing-search-item__info">
# <a class="listing-search-item__link" href="/real-estate-agents/amsterdam/match-real-estate">Match Real Estate</a> </div>
# </section>
# </li>
# <li class="search-list__item">
# <div class="ad-unit ad-unit--serp" id="para-serp-infeed5">
# <script>
#                     googletag.cmd.push(function() {
#                         googletag.display('para-serp-infeed5');
#                     });
#                 </script>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="page__wrapper page__wrapper--content">
# <div class="page__row page__row--pagination">
# <div class="pagination" data-controller="pagination">
# <ul class="pagination__list">
# <li class="pagination__item pagination__item--active">
# <span class="pagination__link">1</span>
# </li>
# <li class="pagination__item">
# <a class="pagination__link" data-action="click-&gt;pagination#onClick" data-pagination-page="2" href="/apartments/amsterdam/page-2">2</a>
# </li>
# <li class="pagination__item">
# <a class="pagination__link" data-action="click-&gt;pagination#onClick" data-pagination-page="3" href="/apartments/amsterdam/page-3">3</a>
# </li>
# <li class="pagination__item">
# <a class="pagination__link" data-action="click-&gt;pagination#onClick" data-pagination-page="4" href="/apartments/amsterdam/page-4">4</a>
# </li>
# <li class="pagination__item">
# <a class="pagination__link" data-action="click-&gt;pagination#onClick" data-pagination-page="5" href="/apartments/amsterdam/page-5">5</a>
# </li>
# <li class="pagination__item pagination__item--spacer">...</li>
# <li class="pagination__item">
# <a class="pagination__link" data-action="click-&gt;pagination#onClick" data-pagination-page="18" href="/apartments/amsterdam/page-18">18</a>
# </li>
# <li class="pagination__item pagination__item--next">
# <a class="pagination__link pagination__link--next" data-action="click-&gt;pagination#onClick" data-pagination-page="2" href="/apartments/amsterdam/page-2">Next</a>
# </li>
# </ul>
# <div class="pagination__summary">1 - 30 of 537 results</div>
# </div>
# </div>
# </div>
# <div class="page__row page__row--billboard">
# <div class="ad-unit ad-unit--serp-billboard" id="para-serp-web-bblb">
# <script>
#                     googletag.cmd.push(function() {
#                         googletag.display('para-serp-web-bblb');
#                     });
#                 </script>
# </div>
# <div class="ad-unit ad-unit--serp-billboard" id="para-serp-mob-mr">
# <script>
#                     googletag.cmd.push(function() {
#                         googletag.display('para-serp-mob-mr');
#                     });
#                 </script>
# </div>
# </div>
# <div class="page__wrapper page__wrapper--city-info">
# <div class="page__row page__row--city-info">
# <div class="page__city-link-lists">
# <div class="page__city-link-list page__city-link-list--popular-cities">
# <h2>Major cities in the Netherlands</h2>
# <ul>
# <li><a href="/apartments/amsterdam">Amsterdam</a></li>
# <li><a href="/apartments/rotterdam">Rotterdam</a></li>
# <li><a href="/apartments/den-haag">Den Haag</a></li>
# <li><a href="/apartments/utrecht">Utrecht</a></li>
# <li><a href="/apartments/eindhoven">Eindhoven</a></li>
# <li><a href="/apartments/amstelveen">Amstelveen</a></li>
# </ul>
# </div>
# <div class="page__city-link-list page__city-link-list--cities-in-province">
# <h2>Top cities in Noord-Holland</h2>
# <ul>
# <li><a href="/apartments/alkmaar">Alkmaar</a></li>
# <li><a href="/apartments/amsterdam">Amsterdam</a></li>
# <li><a href="/apartments/haarlem">Haarlem</a></li>
# <li><a href="/apartments/heemstede">Heemstede</a></li>
# <li><a href="/apartments/heerhugowaard">Heerhugowaard</a></li>
# <li><a href="/apartments/hilversum">Hilversum</a></li>
# <li><a href="/apartments/hoofddorp">Hoofddorp</a></li>
# <li><a href="/apartments/huizen">Huizen</a></li>
# <li><a href="/apartments/purmerend">Purmerend</a></li>
# <li><a href="/apartments/weesp">Weesp</a></li>
# <li><a href="/apartments/zaandam">Zaandam</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <dialog class="dialog dialog--mail-alert-from-search fixed" data-controller="mail-alert-from-search-dialog">
# <form action="/frontend/component/dialog/mail-alert-from-search" class="dialog__form" data-controller="form" data-form-controls-with-constraints='["email"]' method="dialog">
# <input name="filters" type="hidden" value='{"type":"for_rent","city":"amsterdam","lat":52.373436811306,"lon":4.9045250766617}'/>
# <input name="_target_path" type="hidden" value="https://www.pararius.com/apartments/amsterdam?ac=1"/>
# <h6 class="dialog__title">Stay up to date with relevant offerings</h6>
# <div class="dialog__search-filters-summary">
# <div class="search-filters-summary">
# <h5 class="search-filters-summary__header">Your search</h5>
# <ul class="search-filters-summary__list">
# <li class="search-filters-summary__item" data-filter-name="filters[city]">
# <span>Amsterdam</span>
# </li>
# </ul>
# </div>
# </div>
# <p class="dialog__past-results">
# <span>
#                     In the last 5 days there were <strong>82</strong> new properties with these characteristics.
#                 </span>
# </p>
# <div class="dialog__email">
# <div class="text-control" data-controller="text-control" data-text-control-constraints='["email","notBlank"]' data-text-control-name="email" data-text-control-validate-on-connect="">
# <label class="text-control__label" for="text-control-219269070">Email address</label>
# <input class="text-control__control" data-action="input-&gt;text-control#onInput focus-&gt;text-control#onFocus blur-&gt;text-control#onBlur" id="text-control-219269070" name="email" placeholder="" type="email" value=""/>
# </div>
# </div>
# <p class="dialog__legal">
#                     By submitting this form you agree to our <a href="/en/terms-of-use" rel="nofollow" target="_blank">general terms and conditions</a> and <a href="/pararius-privacy-policy" rel="nofollow" target="_blank">privacy policy</a>.
#                 </p>
# <menu class="dialog__menu">
# <button class="dialog__confirm-button" type="submit" value="confirm">
#                     Save search
#                 </button>
# <button autofocus="" class="dialog__cancel-button" value="cancel">
#                     dialog.mail_alert_from_search.button.cancel
#                 </button>
# </menu>
# </form>
# </dialog>
# </div>
# </div>
# <div class="page__wrapper page__wrapper--footer">
# <div class="page__row page__row--footer">
# <footer class="footer footer--compact">
# <div class="footer__links">
# <div class="footer__link">
# <div class="footer__link-header footer__link-header--logo"></div>
# <div class="footer__link-menu">
# <ul class="menu menu--footer">
# <li class="menu__item">
# <a class="menu__link" href="/about-pararius">About Pararius</a>
# </li>
# <li class="menu__item">
# <a class="menu__link" href="/advertise-on-pararius">Advertise</a>
# </li>
# <li class="menu__item">
# <a class="menu__link" href="/news">Press releases</a>
# </li>
# <li class="menu__item">
# <a class="menu__link" href="/info/mediation-fees">Mediation fees</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="footer__link">
# <div class="footer__link-header">
#                     Find a property
#                 </div>
# <div class="footer__link-menu">
# <ul class="menu menu--footer">
# <li class="menu__item">
# <a class="menu__link" href="/register">Sign up for free</a>
# </li>
# <li class="menu__item">
# <a class="menu__link" href="/info/avoid-scams">Avoid scams</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="footer__socials-container">
# <div class="footer__sponsor">
# <svg fill="none" height="141" viewbox="0 0 465 141" width="465" xmlns="http://www.w3.org/2000/svg"><g fill="#fff"><path d="m0 121.89h.24c5.50296.478 11.0302.615 16.55.41 7.162-.353 14.2792-1.334 21.27-2.93 8.3-1.92 16.91-1.53 25.33-.92 7.02.514 14.02 1.21 21 2.09.0019-1.264-.424-2.491-1.2084-3.483-.7843-.991-1.881-1.688-3.1116-1.977-1.8219-.341-3.6673-.541-5.52-.6l-6.88-.07c-4.48 0-9 0-13.45.15-7.63.23-15.26.78-22.9.77-6.9356.066-13.8612-.541-20.68-1.81-.86-.16-3.55-1.12-4.53-1.08-5.52.24-6.11 9.45-6.11 9.45z"></path><path d="m173.76 49.3901c2.93-2.18 5.79-4.21 7.93-8.73 2.44-5.23-23.94-26.76-40.78-40.000034-.42-.33-1.3-1.2-2-.06-.021.037514-.048.071302-.08.1-3.77 4.510004-19 22.670034-21.68 26.180034-2.39 2.06-23.92 27.79-22.87 30.08 5.6 3.32 42.85-6.82 70.57-4.31-6.85 7.44-10.85 10.35-19.85 23.92-2.62 4-6.49 7.93-10 11.44-4.46-6.86-6.56-9.85-14.5-15.31-7.14-4.92-19.49-9.37-23.42-10.63-1.74-.55-1.25 1.48-1.25 1.48 3.76 30.94-3.32 68.6299 2.08 71.5299 7.67 3.15 77.29 7.45 79.32 4.07 0 0 2.74-2.41 4-28.8 1.32-26.6699-1.66-32.7799 1.58-59.4499.19-1.46-6.22-1.2-9.05-1.51zm-66.91.24c6-6.68 28.57-35.53 31.3-39.6 16.28 12.84 21.22 23.65 34.92 32.97-.947 1.2-1.91 2.3866-2.89 3.56-.46.55-.91 1.11-1.38 1.64-.61.68-.72.65-1.64.58-3.39-.25-6.78-.43-10.17-.52-12-.31-24 .77-35.94 1.17-2.23.07-4.47.13-6.7.17h-3.74c-.56.01-3.44-.33-3.76.03zm65.23 63.7599c-.47 9 1.12 11.31.51 19.59-28-.26-40.32-8.29-69.09-8.29-2.4-29.3499 1.47-26.9999-1-52.2499 9.34 4 18.83 10.78 27.7 20.47-.085.1014-.175.1982-.27.29-4.65 4.3-12.25 13.1599-19 16.9999-1 .58-1.63 3.3-.91 2.92 7.67-4 15.34-12.44 20.34-17.4399l1.25-1.25c2.764 3.1451 5.361 6.4329 7.78 9.8499 6.183 8.735 14.013 16.177 23.05 21.91l.12.08c5.31 3.15 4.37-2.25 2.34-3.72-8.331-6.055-15.559-13.497-21.37-22-3.15-4.4399-5.42-7.8999-7.27-10.7399 4.263-3.9773 8.162-8.328 11.65-13 6.182-8.7374 13.394-16.6981 21.48-23.71 1.14.14 2.31.29 3.51.46-3.25 26.67.54 33.16-.82 59.8299z"></path><path d="m236.91 137.83c-3.57 0-4-2.84-4-5s.06-4.62.13-7.2c0-2 .1-4.12.13-6.23-2.56-.15-6-.18-8.49-.18-3.76 0-7.42.12-9.07.19v4.68c0 1.42 0 2.9.1 4.43s.11 3.35.11 5.1c0 2.74-1.39 4.18-4 4.18-.829-.024-1.653-.131-2.46-.32-.38-.07-.77-.15-1.18-.21-.092-.015-.179-.051-.255-.105-.077-.053-.14-.124-.185-.205-.045-.083-.068-.176-.068-.27s.023-.187.068-.27c0 0 .63-1.92.63-14.33 0-3-.21-14.13-.32-16.71-.007-1.804-.171-3.604-.49-5.38-.037-.0764-.056-.1602-.056-.245 0-.0849.019-.1687.056-.245.039-.0812.097-.1522.168-.2077.071-.0554.154-.0939.242-.1123 1.002-.2939 2.037-.4586 3.08-.49 2.86 0 4.78 1.55 4.78 3.86 0 2-.05 7.34-.1 12.39 2.25.14 5.49.17 7.9.17 3.45 0 7.18-.1 9.6-.19-.06-3.51-.16-6.77-.26-9.56-.19-4.54-.46-5.32-.47-5.35-.044-.0761-.067-.1623-.067-.25 0-.0878.023-.174.067-.25.038-.0847.097-.1588.17-.2163.073-.0574.159-.0964.25-.1137 1.002-.2932 2.037-.4578 3.08-.49 2.86 0 4.78 1.55 4.78 3.86s-.05 4.57-.11 6.79-.1 4.34-.1 6.53c0 7.29.31 18.49.75 20.63.016.081.015.164-.002.245s-.05.157-.098.225c-.1.132-.247.221-.41.25-.43.11-.88.19-1.22.26-.876.225-1.776.34-2.68.34z"></path><path d="m261 138.09c-9.65 0-14-7.21-14-13.92 0-7.31 4.56-15.18 14.57-15.18 9.65 0 14 6.81 14 13.13-.03 7.94-5.03 15.97-14.57 15.97zm-.05-25.47c-4.35 0-6.33 5.53-6.33 10.66 0 5.39 2.16 11.19 6.91 11.19 4.38 0 6.37-5.91 6.37-11.4-.03-5.07-2.2-10.45-6.98-10.45z"></path><path d="m300.19 137.73c-.673-.041-1.324-.254-1.89-.62-.651-.396-1.143-1.008-1.39-1.73-.231-.71-.339-1.454-.32-2.2 0-2.17 0-4.08.07-6.07 0-2.15.09-4.4.09-7.2 0-3.88-.28-6.24-4.05-6.24-2 0-4.68 2.32-4.68 6.66 0 2.33.05 4.38.1 6.46s.11 4.32.11 6.86c0 2.78-1.33 4.18-3.94 4.18-1.308-.053-2.607-.233-3.88-.54-.5-.1-.5-.44-.33-.83.276-.58.455-1.202.53-1.84.421-3.588.618-7.198.59-10.81 0-2.57-.1-5.19-.21-7.87-.005-1.959-.378-3.899-1.1-5.72.025-.115.082-.221.165-.305.084-.083.19-.14.305-.165.895-.298 1.828-.467 2.77-.5 2.47 0 4.33 1.2 4.67 2.93 2.084-1.915 4.82-2.963 7.65-2.93 5.12 0 6.9 2 7.51 3.54 1.77-2.31 5.37-3.54 8.25-3.54 7.34 0 8.33 4 8.33 7.92 0 1.85-.05 3.62-.1 5.45s-.11 4-.11 6.4c0 3.12.33 4.92 2 4 ...
# </div>
# <div class="footer__social">
# <ul class="menu menu--footer-social">
# <li class="menu__item menu__item--facebook">
# <a class="menu__link menu__link--facebook" href="https://www.facebook.com/Pararius/" rel="nofollow noopener noreferrer" target="_blank">Facebook</a>
# </li>
# <li class="menu__item menu__item--linkedin">
# <a class="menu__link menu__link--linkedin" href="https://www.linkedin.com/company/pararius-bv" rel="nofollow noopener noreferrer" target="_blank">LinkedIn</a>
# </li>
# <li class="menu__item menu__item--twitter">
# <a class="menu__link menu__link--twitter" href="https://twitter.com/pararius" rel="nofollow noopener noreferrer" target="_blank">Twitter</a>
# </li>
# <li class="menu__item menu__item--instagram">
# <a class="menu__link menu__link--instagram" href="https://www.instagram.com/pararius/" rel="nofollow noopener noreferrer" target="_blank">Instagram</a>
# </li>
# <li class="menu__item menu__item--pinterest">
# <a class="menu__link menu__link--pinterest" href="https://pinterest.com/pararius/" rel="nofollow noopener noreferrer" target="_blank">Pinterest</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="footer__legal">
# <a class="footer__legal-matter footer__legal-matter--terms" href="/en/terms-of-use" rel="nofollow" target="_blank">
#                 Terms and conditions
#             </a>
# <a class="footer__legal-matter footer__legal-matter--privacy" href="/pararius-privacy-policy" rel="nofollow" target="_blank">
#                 Privacy policy
#             </a>
# <a class="footer__legal-matter footer__legal-matter--cookies" href="/en/cookie-policy" rel="nofollow">
#                 Cookie policy
#             </a>
# <span class="footer__legal-matter footer__legal-matter--coc">
#                 COC number: 34242388
#             </span>
# <span class="footer__legal-matter footer__legal-matter--vat">
#                 Vat number: NL8153.68.975B01
#             </span>
# <span class="footer__legal-matter footer__legal-matter--copyright">
#                 © 2006 - 2022 Pararius B.V.
#             </span>
# </div>
# </footer>
# </div>
# </div>
# <div class="page__modal"></div>
# <script>window.pararius = {};</script>
# <script>
#             pararius.env = 'prod';
#
#         pararius.uris = {
#             maps: 'https\u003A\/\/www.pararius.nl\/api\/map',
#             autocomplete: '\/api\/autocomplete',
#         };
#
#         pararius.enabled_feature_toggles = '\u005B\u005D';
#
#         Platform.bundles = {
#             mapbox: '\/frontend\/assets\/bundle\/Shared\/Vendor\/Mapbox\/Mapbox\u002D202e56c69f.js',
#         };
#
#         Platform.uris = {
#             maps: 'https\u003A\/\/www.pararius.nl\/api\/map',
#             autocomplete: '\/api\/autocomplete',
#             get_search_urls: '\/frontend\/get\u002Dsearch\u002Durls',
#             recent_searches: '\/api\/recent\u002Dsearches',
#         };
#
#         Platform.locale = 'en';
#     </script>
# <script src="/frontend/assets/bundle/Pararius/Pararius-a611f39b19.js"></script>
# <script id="notification-template" type="text/html">
#
#
#
#
#
#
#
#
#     <div class="notification notification--animated" data-controller="notification">
#                     <div class="notification__title">%title%</div>
#                             <button class="notification__close" type="button" data-action="click-&gt;notification#onCloseClick"><span>close</span></button>
#                 <div class="notification__message">%message%</div>
#     </div>
#
#         </script>
# </body>
# </html>

# %%
# soup.prettify()
# print(soup.prettify())

# %%
# all sections in a list
lists = soup.find_all('section', class_='listing-search-item')
for list in lists:
    title = list.find("a", class_="listing-search-item__link--title")
    location = list.find("div", class_="listing-search-item__sub-title")
    price = list.find("div", class_="listing-search-item__price")
    area = list.find("li", class_="illustrated-features__item--surface-area")
    bedrooms = list.find("li", class_="illustrated-features__item--number-of-rooms")
    furniture_status = list.find("li", class_="illustrated-features__item--interior")

    info = [title,location,price,area,bedrooms,furniture_status]
    print(info)
# Out:
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/f4a65cfa/bosboom-toussaintstraat">
#
#             Apartment Bosboom Toussaintstraat
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1054 AT Amsterdam (Helmersbuurt)
#         </div>, <div class="listing-search-item__price">
#                 €4,750 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">155 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">5 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Furnished</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/a094142f/oudezijds-voorburgwal">
#
#             Apartment Oudezijds Voorburgwal
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1012 EM Amsterdam (Burgwallen-Oude Zijde)
#         </div>, <div class="listing-search-item__price">
#                 €2,950 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">130 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">5 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Upholstered</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/88112f56/cornelis-vermuydenstraat">
#
#             Apartment Cornelis Vermuydenstraat
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1018 RN Amsterdam (Oostelijke Eilanden/Kadijken)
#         </div>, <div class="listing-search-item__price">
#                 €2,000 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">70 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">3 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Furnished</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/74fd91d6/knsm-laan">
#
#             Apartment KNSM-laan
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1019 LG Amsterdam (Oostelijk Havengebied)
#         </div>, <div class="listing-search-item__price">
#                 €1,850 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">60 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">2 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Furnished</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/a44a562a/michelangelostraat">
#
#             Apartment Michelangelostraat 39 hs
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1077 BR Amsterdam (Apollobuurt)
#         </div>, <div class="listing-search-item__price">
#                 €4,650 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">200 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">5 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Upholstered</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/b9bb2388/hembrugstraat">
#
#             Apartment Hembrugstraat
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1013 XD Amsterdam (Spaarndammer- en Zeeheldenbuurt)
#         </div>, <div class="listing-search-item__price">
#                 €1,950 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">40 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">3 rooms</li>, None]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/67b4a344/revaleiland">
#
#             Apartment Revaleiland
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1014 ZG Amsterdam (Houthavens)
#         </div>, <div class="listing-search-item__price">
#                 €3,750 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">155 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">4 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Furnished</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/28b0571b/nachtwachtlaan">
#
#             Apartment Nachtwachtlaan 98
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1058 EC Amsterdam (Overtoomse Veld)
#         </div>, <div class="listing-search-item__price">
#                 €1,450 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">58 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">2 rooms</li>, None]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/d8f1379e/buitendraaierij">
#
#             Apartment Buitendraaierij
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1021 NM Amsterdam (IJplein/Vogelbuurt)
#         </div>, <div class="listing-search-item__price">
#                 €1,500 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">46 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">2 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Furnished</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/25cf4f18/gerrit-van-der-veenstraat">
#
#             Apartment Gerrit van der Veenstraat
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1077 EE Amsterdam (Apollobuurt)
#         </div>, <div class="listing-search-item__price">
#                 €3,475 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">162 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">4 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Upholstered</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/02d4f573/derde-oosterparkstraat">
#
#             Apartment Derde Oosterparkstraat
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1092 EH Amsterdam (Oosterparkbuurt)
#         </div>, <div class="listing-search-item__price">
#                 €2,200 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">106 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">3 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Upholstered or furnished</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/26b54d99/koningslaan">
#
#             Apartment Koningslaan 24 C
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1075 AD Amsterdam (Willemspark)
#         </div>, <div class="listing-search-item__price">
#                 €3,950 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">83 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">3 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Upholstered</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/519f576a/brederodestraat">
#
#             Apartment Brederodestraat
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1054 VD Amsterdam (Overtoomse Sluis)
#         </div>, <div class="listing-search-item__price">
#                 €1,950 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">43 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">2 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Upholstered</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/f0f31d93/termini">
#
#             Apartment Termini 405
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1025 XM Amsterdam (Buikslotermeer)
#         </div>, <div class="listing-search-item__price">
#                 €1,480 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">69 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">3 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Upholstered</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/4394d415/stadionweg">
#
#             Apartment Stadionweg
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1077 SV Amsterdam (Apollobuurt)
#         </div>, <div class="listing-search-item__price">
#                 €2,250 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">58 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">3 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Upholstered</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/4f03bf96/westerstraat">
#
#             Apartment Westerstraat
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1015 LZ Amsterdam (Jordaan)
#         </div>, <div class="listing-search-item__price">
#                 €1,850 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">50 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">2 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Upholstered</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/fdb4122d/willem-frederik-hermansstraat">
#
#             Apartment Willem Frederik Hermansstraat
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1011 DG Amsterdam (Nieuwmarkt/Lastage)
#         </div>, <div class="listing-search-item__price">
#                 €2,000 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">90 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">3 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Furnished</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/a649f26c/kerkstraat">
#
#             Apartment Kerkstraat 113 4
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1017 GD Amsterdam (Grachtengordel-Zuid)
#         </div>, <div class="listing-search-item__price">
#                 €1,995 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">58 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">2 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Furnished</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/eeecb7cc/runstraat">
#
#             Apartment Runstraat 23 III
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1016 GJ Amsterdam (Grachtengordel-West)
#         </div>, <div class="listing-search-item__price">
#                 €2,000 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">60 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">3 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Furnished</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/house-for-rent/amsterdam/559669fe/prinsengracht">
#
#             House Prinsengracht
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1015 DP Amsterdam (Grachtengordel-West)
#         </div>, <div class="listing-search-item__price">
#                 €1,750 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">50 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">1 room</li>, <li class="illustrated-features__item illustrated-features__item--interior">Furnished</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/8ee95e5c/keizersgracht">
#
#             Apartment Keizersgracht 680 II+III
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1017 ET Amsterdam (Grachtengordel-Zuid)
#         </div>, <div class="listing-search-item__price">
#                 €3,950 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">125 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">3 rooms</li>, None]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/db7c41a3/keizersgracht">
#
#             Apartment Keizersgracht
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1016 EX Amsterdam (Grachtengordel-West)
#         </div>, <div class="listing-search-item__price">
#                 €2,100 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">60 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">1 room</li>, <li class="illustrated-features__item illustrated-features__item--interior">Furnished</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/fcf95e3a/wouwermanstraat">
#
#             Apartment Wouwermanstraat 1 1+2
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1071 LT Amsterdam (Museumkwartier)
#         </div>, <div class="listing-search-item__price">
#                 €3,000 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">140 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">4 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Upholstered</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/8c5c2c0a/sloterkade">
#
#             Apartment Sloterkade 138 D
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1058 HM Amsterdam (Hoofddorppleinbuurt)
#         </div>, <div class="listing-search-item__price">
#                 €2,600 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">106 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">3 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Upholstered</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/1a14dbb6/rooseveltlaan">
#
#             Apartment Rooseveltlaan
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1079 AM Amsterdam (Scheldebuurt)
#         </div>, <div class="listing-search-item__price">
#                 €4,500 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">121 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">4 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Furnished</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/efcfff11/da-costastraat">
#
#             Apartment Da Costastraat
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1053 ZD Amsterdam (Da Costabuurt)
#         </div>, <div class="listing-search-item__price">
#                 €1,750 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">46 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">2 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Furnished</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/studio-for-rent/amsterdam/ef51e193/ferdinand-bolstraat">
#
#             Studio Ferdinand Bolstraat
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1072 LM Amsterdam (Oude Pijp)
#         </div>, <div class="listing-search-item__price">
#                 €1,525 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">35 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">2 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Furnished</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/240fa184/vierwindenstraat">
#
#             Apartment Vierwindenstraat
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1013 CW Amsterdam (Haarlemmerbuurt)
#         </div>, <div class="listing-search-item__price">
#                 €2,350 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">75 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">3 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Furnished</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/98cf4c9c/kleine-wittenburgerstraat">
#
#             Apartment Kleine Wittenburgerstraat
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1018 LZ Amsterdam (Oostelijke Eilanden/Kadijken)
#         </div>, <div class="listing-search-item__price">
#                 €1,900 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">60 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">2 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Furnished</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/1aaa93f9/maria-austriastraat">
#
#             Apartment Maria Austriastraat
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1087 JC Amsterdam (IJburg West)
#         </div>, <div class="listing-search-item__price">
#                 €1,950 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">39 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">1 room</li>, <li class="illustrated-features__item illustrated-features__item--interior">Upholstered or furnished</li>]
# [<a class="listing-search-item__link listing-search-item__link--title" href="/apartment-for-rent/amsterdam/fd4b1755/biesboschstraat">
#
#             Apartment Biesboschstraat
#
#                             </a>, <div class="listing-search-item__sub-title">
#             1078 MK Amsterdam (Scheldebuurt)
#         </div>, <div class="listing-search-item__price">
#                 €2,100 per month
#             </div>, <li class="illustrated-features__item illustrated-features__item--surface-area">80 m²</li>, <li class="illustrated-features__item illustrated-features__item--number-of-rooms">3 rooms</li>, <li class="illustrated-features__item illustrated-features__item--interior">Upholstered</li>]

# %%
# lists = soup.find_all('section', class_='listing-search-item')
# for list in lists:
#     title = list.find("a", class_="listing-search-item__link--title").text.replace('\n', '').strip()
#     location = list.find("div", class_="listing-search-item__sub-title").text.replace('\n', '').strip()
#     price = list.find("div", class_="listing-search-item__price").text.replace('\n', '').strip()
#     area = list.find("li", class_="illustrated-features__item--surface-area").text.replace('\n', '').strip()
#     bedrooms = list.find("li", class_="illustrated-features__item--number-of-rooms").text.replace('\n', '').strip()
#     furniture_status = list.find("li", class_="illustrated-features__item--interior").text.replace('\n', '').strip()

#     info = [title,location,price,area,bedrooms,furniture_status]
#     print(info)

# %%
real_estate = {"title":title}

# %%
# all sections in a list
lists = soup.find_all('section', class_='listing-search-item')
for list in lists:
    title = list.find("a", class_="listing-search-item__link--title")
    if title:
        title = title.text.strip()
    
    location = list.find("div", class_="listing-search-item__sub-title")
    if location:
        location = location.text.strip()
    
    price = list.find("div", class_="listing-search-item__price")
    if price:
        price = price.text.strip()
    
    area = list.find("li", class_="illustrated-features__item--surface-area")
    if area:
        area = area.text.strip()
    
    bedrooms = list.find("li", class_="illustrated-features__item--number-of-rooms")
    if bedrooms:
        bedrooms = bedrooms.text.strip()

    furniture_status = list.find("li", class_="illustrated-features__item--interior")
    if furniture_status:
        furniture_status = furniture_status.text.strip()

    info = [title,location,price,area,bedrooms,furniture_status]
    print(info)
# Out:
# ['Apartment Bosboom Toussaintstraat', '1054 AT Amsterdam (Helmersbuurt)', '€4,750 per month', '155 m²', '5 rooms', 'Furnished']
# ['Apartment Oudezijds Voorburgwal', '1012 EM Amsterdam (Burgwallen-Oude Zijde)', '€2,950 per month', '130 m²', '5 rooms', 'Upholstered']
# ['Apartment Cornelis Vermuydenstraat', '1018 RN Amsterdam (Oostelijke Eilanden/Kadijken)', '€2,000 per month', '70 m²', '3 rooms', 'Furnished']
# ['Apartment KNSM-laan', '1019 LG Amsterdam (Oostelijk Havengebied)', '€1,850 per month', '60 m²', '2 rooms', 'Furnished']
# ['Apartment Michelangelostraat 39 hs', '1077 BR Amsterdam (Apollobuurt)', '€4,650 per month', '200 m²', '5 rooms', 'Upholstered']
# ['Apartment Hembrugstraat', '1013 XD Amsterdam (Spaarndammer- en Zeeheldenbuurt)', '€1,950 per month', '40 m²', '3 rooms', None]
# ['Apartment Revaleiland', '1014 ZG Amsterdam (Houthavens)', '€3,750 per month', '155 m²', '4 rooms', 'Furnished']
# ['Apartment Nachtwachtlaan 98', '1058 EC Amsterdam (Overtoomse Veld)', '€1,450 per month', '58 m²', '2 rooms', None]
# ['Apartment Buitendraaierij', '1021 NM Amsterdam (IJplein/Vogelbuurt)', '€1,500 per month', '46 m²', '2 rooms', 'Furnished']
# ['Apartment Gerrit van der Veenstraat', '1077 EE Amsterdam (Apollobuurt)', '€3,475 per month', '162 m²', '4 rooms', 'Upholstered']
# ['Apartment Derde Oosterparkstraat', '1092 EH Amsterdam (Oosterparkbuurt)', '€2,200 per month', '106 m²', '3 rooms', 'Upholstered or furnished']
# ['Apartment Koningslaan 24 C', '1075 AD Amsterdam (Willemspark)', '€3,950 per month', '83 m²', '3 rooms', 'Upholstered']
# ['Apartment Brederodestraat', '1054 VD Amsterdam (Overtoomse Sluis)', '€1,950 per month', '43 m²', '2 rooms', 'Upholstered']
# ['Apartment Termini 405', '1025 XM Amsterdam (Buikslotermeer)', '€1,480 per month', '69 m²', '3 rooms', 'Upholstered']
# ['Apartment Stadionweg', '1077 SV Amsterdam (Apollobuurt)', '€2,250 per month', '58 m²', '3 rooms', 'Upholstered']
# ['Apartment Westerstraat', '1015 LZ Amsterdam (Jordaan)', '€1,850 per month', '50 m²', '2 rooms', 'Upholstered']
# ['Apartment Willem Frederik Hermansstraat', '1011 DG Amsterdam (Nieuwmarkt/Lastage)', '€2,000 per month', '90 m²', '3 rooms', 'Furnished']
# ['Apartment Kerkstraat 113 4', '1017 GD Amsterdam (Grachtengordel-Zuid)', '€1,995 per month', '58 m²', '2 rooms', 'Furnished']
# ['Apartment Runstraat 23 III', '1016 GJ Amsterdam (Grachtengordel-West)', '€2,000 per month', '60 m²', '3 rooms', 'Furnished']
# ['House Prinsengracht', '1015 DP Amsterdam (Grachtengordel-West)', '€1,750 per month', '50 m²', '1 room', 'Furnished']
# ['Apartment Keizersgracht 680 II+III', '1017 ET Amsterdam (Grachtengordel-Zuid)', '€3,950 per month', '125 m²', '3 rooms', None]
# ['Apartment Keizersgracht', '1016 EX Amsterdam (Grachtengordel-West)', '€2,100 per month', '60 m²', '1 room', 'Furnished']
# ['Apartment Wouwermanstraat 1 1+2', '1071 LT Amsterdam (Museumkwartier)', '€3,000 per month', '140 m²', '4 rooms', 'Upholstered']
# ['Apartment Sloterkade 138 D', '1058 HM Amsterdam (Hoofddorppleinbuurt)', '€2,600 per month', '106 m²', '3 rooms', 'Upholstered']
# ['Apartment Rooseveltlaan', '1079 AM Amsterdam (Scheldebuurt)', '€4,500 per month', '121 m²', '4 rooms', 'Furnished']
# ['Apartment Da Costastraat', '1053 ZD Amsterdam (Da Costabuurt)', '€1,750 per month', '46 m²', '2 rooms', 'Furnished']
# ['Studio Ferdinand Bolstraat', '1072 LM Amsterdam (Oude Pijp)', '€1,525 per month', '35 m²', '2 rooms', 'Furnished']
# ['Apartment Vierwindenstraat', '1013 CW Amsterdam (Haarlemmerbuurt)', '€2,350 per month', '75 m²', '3 rooms', 'Furnished']
# ['Apartment Kleine Wittenburgerstraat', '1018 LZ Amsterdam (Oostelijke Eilanden/Kadijken)', '€1,900 per month', '60 m²', '2 rooms', 'Furnished']
# ['Apartment Maria Austriastraat', '1087 JC Amsterdam (IJburg West)', '€1,950 per month', '39 m²', '1 room', 'Upholstered or furnished']
# ['Apartment Biesboschstraat', '1078 MK Amsterdam (Scheldebuurt)', '€2,100 per month', '80 m²', '3 rooms', 'Upholstered']

# %%
# all sections in a list
title_ = []
location_ = []
price_ = []
area_ = []
bedrooms_ = []
furniture_status_ = []

lists = soup.find_all('section', class_='listing-search-item')
for list in lists:
    title = list.find("a", class_="listing-search-item__link--title")
    if title:
        title = title.text.strip()
    
    location = list.find("div", class_="listing-search-item__sub-title")
    if location:
        location = location.text.strip()
    
    price = list.find("div", class_="listing-search-item__price")
    if price:
        price = price.text.strip()
    
    area = list.find("li", class_="illustrated-features__item--surface-area")
    if area:
        area = area.text.strip()
    
    bedrooms = list.find("li", class_="illustrated-features__item--number-of-rooms")
    if bedrooms:
        bedrooms = bedrooms.text.strip()

    furniture_status = list.find("li", class_="illustrated-features__item--interior")
    if furniture_status:
        furniture_status = furniture_status.text.strip()

    # info = [title,location,price,area,bedrooms,furniture_status]
    # print(info)
    title_.append(title)
    location_.append(location)
    price_.append(price)
    area_.append(area)
    bedrooms_.append(bedrooms)
    furniture_status_.append(furniture_status)

# %%
import re

# %% [markdown]
# **Data Cleaning**

# %%
def regex_cleaner(x):
    reg = re.compile(r'\d+')
    
    final_x = []
    for i in range(len(x)):
        rectified_x = reg.findall(x[i])
        rectified_x = "".join(rectified_x)
        final_x.append(rectified_x)
    return final_x

# %%
new_area = regex_cleaner(area_)
new_price = regex_cleaner(price_)
new_bedrooms = regex_cleaner(bedrooms_)

# %%
# practice code
# area_regex = re.compile(r'\d+')
# area_2 = area_

# %%
# practice code
# area_regex.findall(area_2[0])

# %%
# practice code
# area_4 = []
# for i in range(len(area_2)):
#     area_3 = area_regex.findall(area_2[i])
#     area_3 = "".join(area_3)
#     area_4.append(area_3)
# area_4

# %%
# practice code
# price_regex = re.compile(r'\d+')
# price_2 = price_
# "".join(price_regex.findall(price_2[0]))

# %%
# practice code
# bed_regex = re.compile(r'\d+')
# bed_2 = bedrooms_
# "".join(bed_regex.findall(bed_2[0]))

# %% [markdown]
# **Creating the Data Frame**

# %%
details = {'title':title_, 'location':location_,'price':new_price,'area':new_area,'bedrooms':new_bedrooms,'furniture_status':furniture_status_}

# %%
real_estate = pd.DataFrame(details)
real_estate.isna().sum()
# Out:
# title               0
# location            0
# price               0
# area                0
# bedrooms            0
# furniture_status    3
# dtype: int64

# %%
real_estate.to_csv('scraped_estate_2.csv',index=False)
